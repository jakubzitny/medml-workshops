# %% [markdown]
# # Medical data processing and ML workshops - motivation, data, tools

# %% [markdown]
# Workshop for medical students interested in data processing and machine learning, for ML students interested in medical data, imaging and for anyone with programming or data analysis background interested in ML.
#
# This workshop is a follow-up to [Wünsch day](https://www.youtube.com/watch?v=5SHklEqgjFQ&list=PL0AQ9p7Li83z8tWgKwuj-LqMaZtknk9uY&index=2&t=2s) where we briefly introduced the history of cybernetics and current AI trends in hospitals.
#
# <br />
#
# **Organized by**
#
# * [Jakub Žitný](https://twitter.com/jakubzitny) — developer at [Avocode](http://avocode.com), PhD student at [FIT](http://fit.cvut.cz)
# * [HackPrague](http://hackprague.com)
# * [Vzdělání Budoucnosti](http://vzdelanibudoucnosti.cz)
#
# <br />
#
#
# **Contents (available in the left panel as well)**:
#
#
# * [Machine Learning crash course (theory)](#scrollTo=c_XpDbcA7Ejd)
# * [ML in medical imaging](#scrollTo=w43cSxpA8qhU)
# * [Technical basics and tooling](#scrollTo=uu5WYqIY9M4A)
# * (break)
# * [Medical data](#scrollTo=WEdH1B-i9QKj)
# * [Train your first neural networks](#scrollTo=-cirh8UK9TQ1)
# * [Resources and next steps](#scrollTo=Xs0dhUyU9VHr)

# %% [markdown]
# **Prerequisities**
#
#
# 1. Browser
# 2. Copy of this notebook (click on *File -> Save a copy in Drive...* and open the copy in new tab).
# 3. Thats it!
#
# *If you have technical or moral problems with Colaboratory or Google itself, you can clone the [medml-workshops repo](https://github.com/jakubzitny/medml-workshops)*, install [this Anaconda env](https://github.com/ImprolabFIT/BI-SVZ-coursework/tree/master/tutorials/files/1/env) and open the `./medml-intro.ipynb` in Jupyter Notebook.

# %% [markdown]
# # Machine Learning crash course

# %% [markdown]
# ## Glossary
#
# * Artificial Intelligence
# * Machine Learning
# * Deep Learning
# * Neural Networks
# * Computer Vision
# * Medical Imaging

# %% [markdown]
# ## History and recent successes

# %% [markdown]
# ## Neural network basics
#
# - why not play with it first? — https://playground.tensorflow.org

# %% [markdown]
# # Medical Imaging
#
# * radiology, experts, human factor, hospitals
# * imaging research before ML / DL
# * ML in medical imaging
#   * X-Ray, CT, Mammo
#   * MRI
#   * Ultrasound
#   * PET
#
# * other "imaging"
#  * dermoscopy
#  * retinal fungus
#
# * problems
#
# * data formats
#   * DICOM
#   * Nifty

# %% [markdown]
# # Technical basics and tooling

# %% [markdown]
# ## Introduction to Colab and Jupyter notebooks
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/notebooks/welcome.ipynb) Colaboratory basics and resources
#
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jakubzitny/medml-workshops/blob/master/jupyter-introduction.ipynb) Jupyter basics

# %% [markdown]
# text cell [with Markdown](https://www.markdownguide.org/cheat-sheet)

# %%
# this is Python code
21 + 21
# Out:
# 42

# %%
import time

# %%
# Jupyter magic commands

# %%time

time.sleep(2)

print("lul")
# Out:
# lul
# CPU times: user 1.47 ms, sys: 493 µs, total: 1.97 ms
# Wall time: 2 s

# %%
# %%html
# <!-- ukázka magického příkazu a html v notebooku -->
#
# <div>
#   <b>HTML v notebooku:</b>
#   <br />
#   <div style="height: 200px; width: 200px; background: #f00"></div>
# </div>

# %% [markdown]
# ### Shortcuts
#
#
#
# *   **Delete a cell** — Ctrl + M + D
# *  **Execute a cell** — Shift + enter
# * **Enter cell edit mode** — Enter
# * **Move up** — Arrow Up
# * **Move down** — Arrow Down

# %% [markdown]
# ## Python crash course
#
# Small Python tips will help you to understand the code that wil follow. Stolen from [@lukasbrchl](https://github.com/ImprolabFIT/BI-SVZ-coursework/blob/master/tutorials/files/1/python-introduction.ipynb) <3
#
# Useful links:
# * [PEP 8 -- Style Guide for Python Code](https://www.python.org/dev/peps/pep-0008/)
# * [Intermediate Python](https://book.pythontips.com/en/latest/)

# %% [markdown]
# ### \*args, \*\*kwargs
#
# \*args and \*\*kwargs are mostly used in function definitions. \*args and \*\*kwargs allow you to pass a variable number of arguments to a function. What variable means here is that you do not know beforehand how many arguments can be passed to your function by the user so in this case you use these two keywords.

# %%
def say(phrase, *names):
    for i in names:
        print(phrase, ' ', i)

# %%
say('Hi', 'Alex', 'Kuba')
# Out:
# Hi   Alex
# Hi   Kuba

# %% [markdown]
# **\*\*kwargs** allows you to pass keyworded variable length of arguments to a function. You should use \*\*kwargs if you want to handle named arguments in a function.

# %%
def show(*args, **kwargs):
    for i, v in enumerate(args):
        print('Argument', i, '=', v)
    
    for k, v in kwargs.items():
        print('Keyword argument', k, '=', v)

# %%
show(5, 'Hello', [1, 2, 3], number=12, name='Bob')
# Out:
# Argument 0 = 5
# Argument 1 = Hello
# Argument 2 = [1, 2, 3]
# Keyword argument number = 12
# Keyword argument name = Bob

# %%
ids = [4, 1, 6]
names = {'Manager': 'Bob', 
         'Worker': 'John',
         'Workers number': 2}

show(*ids, *names)
# Out:
# Argument 0 = 4
# Argument 1 = 1
# Argument 2 = 6
# Argument 3 = Manager
# Argument 4 = Worker
# Argument 5 = Workers number

# %% [markdown]
# ### Collections
#
# Python is a dynamic typed interpreted language, therefore you can mixup different objects inside the collection.

# %% [markdown]
# #### Lists

# %%
# blank list
a = []
a = list()

# inline list definition
a = [1, 2, 4, 5]
print('inline list definition:', a)

# value assignment by index
a[0] = '10'
print('value assignment by index:', a)

# add to list
a.append(11)
print('add to list:', a)

# delete by index
del a[2]
print('delete by index:', a)
# Out:
# inline list definition: [1, 2, 4, 5]
# value assignment by index: ['10', 2, 4, 5]
# add to list: ['10', 2, 4, 5, 11]
# delete by index: ['10', 2, 5, 11]

# %%
# List comprehension
# List comprehensions provide a short and concise way to create lists.

a = [i**2 for i in range(12) if i % 2 == 0]
print('List comprehension:', a)

a = []
for i in range(12):
    if i % 2 == 0:
        a.append(i**2)
print('For if:', a)
# Out:
# List comprehension: [0, 4, 16, 36, 64, 100]
# For if: [0, 4, 16, 36, 64, 100]

# %% [markdown]
# #### Tuples
# Immutable list

# %%
# Inline definition ONLY! (immutable)
t = (1,2,3,4)
t = 1, 2, 3, 4
t = tuple({1,2,3,5})
t
# Out:
# (1, 2, 3, 5)

# %%
t[0] = 10 # will not work

# %%
del t[0] # will not work

# %% [markdown]
# #### Dicts
# Simple key-value collection

# %%
# blank dict
a = {}
a = dict()

# inline dict definition
d = {
    'a': 10,
    1: 16,
    1.5: 12
}
print('inline dict definition:', d)

# value assignment by key
d[1] = 18
# even if does not exist
d['newkey'] = 'value'
print('value assignment by key', d)
# Out:
# inline dict definition: {'a': 10, 1: 16, 1.5: 12}
# value assignment by key {'a': 10, 1: 18, 1.5: 12, 'newkey': 'value'}

# %%
# check if key exists in dict
'newkey' in d
d.__contains__('newkey')
# Out:
# True

# %%
# delete by key
del d[1.5]
print(d)
# Out:
# {'a': 10, 1: 18, 'newkey': 'value'}

# %%
d.items()
# Out:
# dict_items([('a', 10), (1, 18), ('newkey', 'value')])

# %%
# iteration over dict
for key, value in d.items():
    print(key, ' ', value)
# Out:
# a   10
# 1   18
# newkey   value

# %%
print('Keys:', d.keys())
print('Values:', d.values())
# Out:
# Keys: dict_keys(['a', 1, 'newkey'])
# Values: dict_values([10, 18, 'value'])

# %%
# By default every instance of some class has dict representation 
# It consists of attributes names (keys) and its' values, methods are not serialized

class A:
    a = 5
    def __init__(self, d):
        self.d = d
        self._g = d
    
    def met(self):
        return 6

obj = A(3)
obj.__dict__
# Out:
# {'_g': 3, 'd': 3}

# %%
# Dict comprehension
# Dict comprehensions provide a short and concise way to create dicts.

{
    i : i**2
    for i in range(12)
    if i % 2 == 0
}
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %% [markdown]
# ### Ranges

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(2, 5))
# Out:
# [2, 3, 4]

# %%
list(range(10, 5, -1))
# Out:
# [10, 9, 8, 7, 6]

# %% [markdown]
# ### Map, Filter and Reduce

# %%
items = [1, 2, 3, 4, 5]

mapped = list(map(lambda x: x**2, items))
print(mapped)
# Out:
# [1, 4, 9, 16, 25]

# %%
squared = []
for i in items:
    squared.append(i**2)
print(squared)
# Out:
# [1, 4, 9, 16, 25]

# %%
items = range(-5, 5)

list(filter(lambda x: x > 0, items))
# Out:
# [1, 2, 3, 4]

# %%
filtered = []
for i in items:
    if i > 0:
        filtered.append(i)
print(filtered)
# Out:
# [1, 2, 3, 4]

# %%
from functools import reduce
items = [1, 2, 3, 4, 5]

reduce(lambda x,y: x*y, items)
# Out:
# 120

# %%
product = 1
for num in items:
    product = product * num
product
# Out:
# 120

# %% [markdown]
# ## Python data libraries
#
# - np, scipy, matplotlib, pandas
# - tf

# %%
import numpy as np
import scipy
import matplotlib
import matplotlib.pyplot as plt
import cv2
import yaml

# %matplotlib inline

# %%
print(np.__version__)
print(scipy.__version__)
print(matplotlib.__version__)
print(cv2.__version__)
# Out:
# 1.16.4
# 1.3.0
# 3.0.3
# 3.4.3

# %% [markdown]
# ### Numpy
#
# [NumPy](http://www.numpy.org/) is the fundamental package for scientific computing with Python. It contains among other things:
#
# 1. a powerful N-dimensional array object
# 1. sophisticated (broadcasting) functions
# 1. tools for integrating C/C++ and Fortran code
# 1. useful linear algebra, Fourier transform, and random number capabilities
#
# For more info visit NumPy documentation page!
#
# Here is an easy example just for fun!

# %%
def plus(x, y):
    return x + y

# %%
plus_vect = np.vectorize(plus)

# %%
plus(10, 11)
# Out:
# 21

# %%
plus([10,100,90], 11) # will not work

# %%
plus_vect([10,100,90], 11)
# Out:
# array([ 21, 111, 101])

# %%
plus_vect(10, 11)
# Out:
# array(21)

# %% [markdown]
# ### Scikit
#
# * [scikit-learn ML intro](https://scikit-learn.org/stable/tutorial/basic/tutorial.html#machine-learning-the-problem-setting)

# %%
from sklearn import datasets
iris = datasets.load_iris()
digits = datasets.load_digits()

print(digits.data)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]

# %%
digits.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
from sklearn import svm
clf = svm.SVC(gamma=0.001, C=100.)

# %%
clf.fit(digits.data[:-1], digits.target[:-1])
# Out:
# SVC(C=100.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf.predict(digits.data[-1:])
# Out:
# array([8])

# %% [markdown]
# ### Matplotlib

# %%
def generate_vector(start, end, step):
    return np.arange(start, end, step)

start = -4*np.pi
end = 4*np.pi
step = 0.01

x = generate_vector(start, end, step)

# %%
import numpy as np
import matplotlib.pyplot as plt

y = np.sin(x)
plt.title('Funkce sin(x)')
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Alternative tools
#
# - theano, pytorch
# - [Julia](https://julialang.org) for data analysis

# %% [markdown]
# # Medical data
#
# - DICOM vs NII

# %% [markdown]
# ## Load data from Google Drive
#
# Copy [this folder](https://drive.google.com/open?id=1DBhpHQjgZBtYvy4IY0ynVqoEYyYrW43T) to your private Google Drive (click on *kits_cases_subset -> Add to My Drive*).
#
# It's a subset of [KiTS Challenge data](https://kits19.grand-challenge.org/data/) – segmented kidney tumours in Nifti format.

# %%
# connect to gdrive

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
import os
import numpy as np
import nibabel as nib

data_path = '/content/drive/My Drive/kits_cases_subset'
imaging_name = 'imaging.nii.gz'
segmentation_name = 'segmentation.nii.gz'

# %%
# example load

case = nib.load(os.path.join(data_path, 'case_00000', imaging_name))
seg = nib.load(os.path.join(data_path, 'case_00000', segmentation_name))

# %%
# %%time
vol = case.get_data()
seg = seg.get_data()
seg = seg.astype(np.int32)
# Out:
# CPU times: user 6.47 s, sys: 2.29 s, total: 8.75 s
# Wall time: 9.26 s

# %% [markdown]
# ## Visualize example cases

# %%
# setup matplotlib first

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

matplotlib.rcParams['figure.dpi'] = 150

# %%
plt.imshow(vol[200])
plt.show()

# %%
case2 = nib.load(os.path.join(data_path, 'case_00002', imaging_name))
vol2 = case2.get_data()
plt.imshow(vol2[200])
plt.show()

# %% [markdown]
# # KiTS utility functions
#
# https://github.com/neheller/kits19

# %%
import argparse
import scipy.misc
import nibabel as nib
import numpy as np

def load_case(cid):
    vol = nib.load('test.nii.gz')
    seg = None #nib.load(str(case_path / "segmentation.nii.gz"))
    return vol, seg
  
  
# Constants
DEFAULT_KIDNEY_COLOR = [255, 0, 0]
DEFAULT_TUMOR_COLOR = [0, 0, 255]
DEFAULT_HU_MAX = 512
DEFAULT_HU_MIN = -512
DEFAULT_OVERLAY_ALPHA = 0.3


def hu_to_grayscale(volume, hu_min, hu_max):
    # Clip at max and min values if specified
    if hu_min is not None or hu_max is not None:
        volume = np.clip(volume, hu_min, hu_max)

    # Scale to values between 0 and 1
    mxval = np.max(volume)
    mnval = np.min(volume)
    im_volume = (volume - mnval)/max(mxval - mnval, 1e-3)

    # Return values scaled to 0-255 range, but *not cast to uint8*
    # Repeat three times to make compatible with color overlay
    im_volume = 255*im_volume
    return np.stack((im_volume, im_volume, im_volume), axis=-1)


def class_to_color(segmentation, k_color, t_color):
    # initialize output to zeros
    shp = segmentation.shape
    seg_color = np.zeros((shp[0], shp[1], shp[2], 3), dtype=np.float32)

    # set output to appropriate color at each location
    seg_color[np.equal(segmentation,1)] = k_color
    seg_color[np.equal(segmentation,2)] = t_color
    return seg_color


def overlay(volume_ims, segmentation_ims, segmentation, alpha):
    # Get binary array for places where an ROI lives
    segbin = np.greater(segmentation, 0)
    repeated_segbin = np.stack((segbin, segbin, segbin), axis=-1)
    # Weighted sum where there's a value to overlay
    overlayed = np.where(
        repeated_segbin,
        np.round(alpha*segmentation_ims+(1-alpha)*volume_ims).astype(np.uint8),
        np.round(volume_ims).astype(np.uint8)
    )
    return overlayed


def visualize(cid, destination, hu_min=DEFAULT_HU_MIN, hu_max=DEFAULT_HU_MAX, 
    k_color=DEFAULT_KIDNEY_COLOR, t_color=DEFAULT_TUMOR_COLOR,
    alpha=DEFAULT_OVERLAY_ALPHA):
    # Prepare output location
    out_path = Path(destination)
    if not out_path.exists():
        out_path.mkdir()  

    # Load segmentation and volume
    vol, seg = load_case(cid)
    vol = vol.get_data()
    # seg = seg.get_data()
    # seg = seg.astype(np.int32)
    
    # Convert to a visual format
    vol_ims = hu_to_grayscale(vol, hu_min, hu_max)
    # seg_ims = class_to_color(seg, k_color, t_color)
    
    # Overlay the segmentation colors
    # viz_ims = overlay(vol_ims, seg_ims, seg, alpha)

    # Save individual images to disk
    for i in range(vol_ims.shape[0]):
        fpath = out_path / ("{:05d}.png".format(i))
        scipy.misc.imsave(str(fpath), vol_ims[i])

# %% [markdown]
# # Train your first neural networks

# %% [markdown]
# Set up a GPU in *Runtime -> Change runtime type -> Hardware accellerator -> GPU*

# %%
import tensorflow as tf
import os

print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 1.13.1
# 2.2.4-tf

# %% [markdown]
# ## Data
#
# fetch some data to play with

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### MNIST

# %%
from keras.datasets import mnist
(mnist_train, mnist_train_labels_sparse), (mnist_test, mnist_test_labels_sparse) = mnist.load_data()
# Out:
# Using TensorFlow backend.
# ...
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
mnist_train_norm = mnist_train.astype('float32') / 255
mnist_test_norm = mnist_test.astype('float32') / 255

mnist_train_labels = to_categorical(mnist_train_labels_sparse)
mnist_test_labels = to_categorical(mnist_test_labels_sparse)

# %% [markdown]
# ### Fashion MNIST

# %%
from keras.datasets import fashion_mnist
(fmnist_train, fmnist_train_labels_sparse), (fmnist_test, fmnist_test_labels_sparse) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
mnist_train_norm = mnist_train.astype('float32') / 255
mnist_test_norm = mnist_test.astype('float32') / 255

mnist_train_labels = to_categorical(mnist_train_labels_sparse)
mnist_test_labels = to_categorical(mnist_test_labels_sparse)

# %% [markdown]
# ### CIFAR

# %%
from tensorflow.keras.datasets import cifar10
(cifar_train, cifar_train_labels_sparse), (cifar_test, cifar_test_labels_sparse) = cifar10.load_data()
# Out:
# ...
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
cifar_train_norm = cifar_train.astype('float32') / 255
cifar_test_norm = cifar_test.astype('float32') / 255

cifar_train_labels = to_categorical(cifar_train_labels_sparse)
cifar_test_labels = to_categorical(cifar_test_labels_sparse)

# %% [markdown]
# ## Simple NN in Keras

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, UpSampling2D, Activation, Dropout
from tensorflow.keras.optimizers import RMSprop
import numpy as np

import time
from timeit import default_timer as timer
from datetime import timedelta

# %%
# define a model

def modelSimpleNN():
  model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation=tf.nn.relu),
    Dense(10, activation=tf.nn.softmax)
  ])
  
  return model

# %%
# compile the model

model = modelSimpleNN()

learning_rate = 0.0001
loss = 'categorical_crossentropy'
opt = tf.train.AdamOptimizer(learning_rate)

model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])

# %%
# train it

epochs = 10
batch_size = 32

start = timer()
history = model.fit(mnist_train_norm, mnist_train_labels, batch_size=batch_size, epochs=epochs, validation_data=(mnist_test_norm, mnist_test_labels), shuffle=True)

end = timer()
print(timedelta(seconds=end-start))
# Out:
# Train on 60000 samples, validate on 10000 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.6046 - acc: 0.8482 - val_loss: 0.3104 - val_acc: 0.9153
# Epoch 2/10
# 60000/60000 [==============================] - 5s 84us/sample - loss: 0.2842 - acc: 0.9219 - val_loss: 0.2449 - val_acc: 0.9301
# Epoch 3/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.2327 - acc: 0.9356 - val_loss: 0.2087 - val_acc: 0.9413
# Epoch 4/10
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.1992 - acc: 0.9439 - val_loss: 0.1835 - val_acc: 0.9468
# Epoch 5/10
# ...

# %%
# visualize the training process

# %matplotlib inline
import matplotlib
matplotlib.rcParams['figure.dpi'] = 150

# get training and test loss histories
training_loss = history.history['loss']
training_acc = history.history['acc']

# test_loss = history.history['val_loss']
val_acc = history.history['val_acc']


# create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

plt.plot(epoch_count, training_acc, 'b--')
plt.plot(epoch_count, val_acc, 'r--')

# test_loss = history.history['val_loss']
#plt.plot(epoch_count, test_loss, 'b-')
plt.legend(['Training Accuracy', 'Validation Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show();

# %%
# does it really work?

first_image = mnist_test_norm[0]

model.predict(np.array([first_image]))
# Out:
# array([[1.3518658e-05, 1.3655503e-07, 1.8948838e-04, 2.0091978e-03,
#         7.4833537e-08, 2.9331142e-05, 2.7534275e-09, 9.9768651e-01,
#         1.8062294e-05, 5.3650132e-05]], dtype=float32)

# %%
mnist_test_labels_sparse[0]
# Out:
# 7

# %%
first_image = np.array(first_image, dtype='float')
pixels = first_image.reshape((28, 28))
plt.imshow(pixels, cmap='gray')
plt.show()

# %% [markdown]
# ## Simple CNN with CIFAR data

# %%
# define a model

def modelSimpleCNN(num_classes=10, input_shape=(28, 28)):
  model = Sequential()
  model.add(Conv2D(filters=28, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
  model.add(MaxPool2D())
  model.add(Conv2D(filters=56, kernel_size=(3, 3), activation='relu'))
  model.add(MaxPool2D())
  model.add(Flatten())
  model.add(Dense(num_classes, activation='softmax'))
  
  return model

# %%
# compile the model

model = modelSimpleCNN(input_shape=(32, 32, 3))

learning_rate = 0.0001

loss = 'categorical_crossentropy'
opt = tf.train.AdamOptimizer(learning_rate)

model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
epochs = 10
batch_size = 32

start = timer()
history = model.fit(cifar_train_norm, cifar_train_labels, batch_size=batch_size, epochs=epochs, validation_data=(cifar_test_norm, cifar_test_labels), shuffle=True)

end = timer()
print(timedelta(seconds=end-start))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 55s 1ms/sample - loss: 1.8518 - acc: 0.3449 - val_loss: 1.6163 - val_acc: 0.4284
# Epoch 2/10
# 50000/50000 [==============================] - 54s 1ms/sample - loss: 1.5574 - acc: 0.4493 - val_loss: 1.4951 - val_acc: 0.4745
# Epoch 3/10
# 50000/50000 [==============================] - 56s 1ms/sample - loss: 1.4610 - acc: 0.4855 - val_loss: 1.4176 - val_acc: 0.5035
# Epoch 4/10
# 50000/50000 [==============================] - 56s 1ms/sample - loss: 1.3952 - acc: 0.5110 - val_loss: 1.3703 - val_acc: 0.5195
# Epoch 5/10
# 50000/50000 [==============================] - 57s 1ms/sample - loss: 1.3424 - acc: 0.5295 - val_loss: 1.3198 - val_acc: 0.5395
# Epoch 6/10
# 50000/50000 [==============================] - 57s 1ms/sample - loss: 1.3027 - acc: 0.5458 - val_loss: 1.3020 - val_acc: 0.5429
# Epoch 7/10
# ...

# %% [markdown]
# ## Let's try TPU
#
# Change to TPU runtime in *Runtime -> Change runtime type -> Hardware accelerator -> TPU*

# %%
import os
print(os.environ['COLAB_TPU_ADDR'])
# Out:
# 10.65.110.106:8470

# %%
# NOTE: TPU setup
# SEE: https://medium.com/tensorflow/tf-keras-on-tpus-on-colab-674367932aa0

try:
  device_name = os.environ['COLAB_TPU_ADDR']
  TPU_ADDRESS = 'grpc://' + device_name
  print('Found TPU at: {}'.format(TPU_ADDRESS))
except KeyError:
  print('TPU not found')
# Out:
# Found TPU at: grpc://10.65.110.106:8470

# %%
# TPU training
tpu_model = tf.contrib.tpu.keras_to_tpu_model(
    model,
    strategy=tf.contrib.tpu.TPUDistributionStrategy(
        tf.contrib.cluster_resolver.TPUClusterResolver(TPU_ADDRESS)))
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Querying Tensorflow master (grpc://10.65.110.106:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, -1, 15827670134418078997)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 318128477749675571)
# ...

# %%
def train_input_fn(batch_size=1024):
  # Convert the inputs to a Dataset.
  dataset = tf.data.Dataset.from_tensor_slices((cifar_train_norm, cifar_train_labels))

  # Shuffle, repeat, and batch the examples.
  dataset = dataset.cache()
  dataset = dataset.shuffle(1000, reshuffle_each_iteration=True)
  dataset = dataset.repeat()
  dataset = dataset.batch(batch_size, drop_remainder=True)
  return dataset

# %%
epochs = 50
batch_size = 1024

start = timer()
history = tpu_model.fit(
    train_input_fn,
    steps_per_epoch = 60,
    epochs=epochs,
)

end = timer()
print(timedelta(seconds=end-start))
# Out:
# Epoch 1/50
# INFO:tensorflow:New input shapes; (re-)compiling: mode=train (# of cores 8), [TensorSpec(shape=(1024,), dtype=tf.int32, name=None), TensorSpec(shape=(1024, 32, 32, 3), dtype=tf.float32, name=None), TensorSpec(shape=(1024, 10), dtype=tf.float32, name=None)]
# INFO:tensorflow:Overriding default placeholder.
# INFO:tensorflow:Remapping placeholder for conv2d_input
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/keras_support.py:302: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Started compiling
# ...

# %% [markdown]
# # Resources and next steps
#
# Stay tuned for updates in https://github.com/jakubzitny/medml-workshops.

# %% [markdown]
# ## Medical Imaging conferences
#
# - [MICCAI](https://www.miccai2019.org), [2018 proceedings](https://www.miccai2018.org/en/MICCAI-2018-PROCEEDINGS.html)
# - [ISBI](https://biomedicalimaging.org/2019/)
# - [MIDL](https://2019.midl.io)

# %% [markdown]
# ## Awesome lists
#
# * [Computer Vision](https://github.com/jbhuang0604/awesome-computer-vision)
# * [GANs](https://github.com/kozistr/Awesome-GANs)
# * [GANs for medical imaging](https://github.com/xinario/awesome-gan-for-medical-imaging)
# * [Signal processing](https://github.com/jakubzitny/papers#cnns-and-rnns-for-signal-processing-and-medical-vision)

# %% [markdown]
# ## Open medical datasets

# %% [markdown]
# - BIDMC (wf), physio-bidmc, static heart dataset, queensland vital signs
# - arrhytmia physionet https://physionet.org/physiobank/database/mitdb/
# - MURA
# - BraTS, ISLES
# - MIMIC (general data + waveforms), mimic-iii !!!
# - Diabetic Retinopathy Detection __
# - Physionet challenge https://physionet.org/challenge/2018/
# - mammo Dream challenge https://www.synapse.org/#!Synapse:syn4224222/wiki/401745
# - othre dream challenges http://dreamchallenges.org
# - http://medvis.org/datasets/ list (openfmri, dtis, ...)
# - https://openneuro.org
# - kaggle
# - MICCAI challenge data !! https://grand-challenge.org/challenges/
# - md.ai data
#     - Hello World Deep Learning Tutorial
#     - The Cancer Genome Atlas - Lung Adenocarcinoma
#     - NLM Lung X Rays
#     - RSNA Pneumonia Detection Challenge
#     - Virtual Colonoscopy
#     - CT Colonography
#     - The Cancer Genome Atlas - Papillary Renal Cell Carcinoma
#     - Clinical Proteomic Tumor Analysis Consortium - Clear Cell Renal Cell Carcinoma
#     - Clinical Proteomic Tumor Analysis Consortium - Pancreatic Ductal Adenocarcinoma
#     - Clinical Proteomic Tumor Analysis Consortium - Uterine Corpus Endometrial Carcinoma
#     - NaF Prostate
#     - Pancreas CT
#     - CT Lymph Nodes
#     - The Cancer Genome Atlas - Kidney Renal Clear Cell Carcinoma
#     - The Cancer Genome Atlas - Breast Invasive Carcinoma
#     - The Cancer Genome Atlas - Rectum Adenocarcinoma
#     - The Cancer Genome Atlas - Ovarian Cancer
#     - The Cancer Genome Atlas - Thyroid Cancer
#     - The Cancer Genome Atlas - Kidney Chromophobe
#     - The Cancer Genome Atlas - Colon Adenocarcinom
#     - The Cancer Genome Atlas - Liver Hepatocellular Carcinoma
#     - The Cancer Genome Atlas - Low Grade Glioma
#     - The Cancer Genome Atlas - Urothelial Bladder Carcinoma
#     - The Cancer Genome Atlas - Uterine Corpus Endometrial Carcinoma
#     - The Cancer Genome Atlas - Cervical Squamous Cell Carcinoma and Endocervical Adenocarcinoma
#     - The Cancer Genome Atlas - Stomach AdenocarcinomaThe Cancer Genome Atlas - Esophageal Carcinoma
#     - The Cancer Genome Atlas - Prostate Adenocarcinoma
#     - The Cancer Genome Atlas - Sarcoma
# - http://rodrigob.github.io/are_we_there_yet/build/ (best models on popular data)
# - more general statistical data http://support.minitab.com/en-us/datasets/
# - eu open data portal https://data.europa.eu/euodp/en/home/
# - aortic mr image set (uk biobank, 500, abdominal?)
# - https://www.smir.ch
# - https://modeldepot.io
# - TODO: https://www.interviewqs.com/blog/free_online_data_sets
# - EMBL-EBI https://www.ebi.ac.uk
